 1097.5774, 1102.8381, 1105.6794, 1110.6064, 1106.3789, 1109.5806, 1111.6381, 1114.6986, 1112.905, 1116.4491, 1118.0817, 1121.5592, 1116.11, 1118.7096, 1120.3986, 1122.6012, 1120.9911, 1124.1604, 1125.441, 1128.1512, 1123.0098, 1125.2798, 1127.0931, 1128.8267, 1127.6288, 1130.9761, 1132.4014, 1135.7532, 1132.1362, 1134.8761, 1136.8611, 1139.0531, 1138.2968, 1142.3365, 1144.5375, 1147.8861, 1144.7413, 1148.0728, 1150.3091, 1152.7242, 1152.1486]
    # stress values at 1 s^-1

strain_10 = [0, 0.000229266, 0.000319036, 0.001285247, 0.004155141, 0.00912738, 0.016246783, 0.023132516, 0.03376399, 0.040409897, 0.044701666, 0.047927104, 0.051040623, 0.056738485, 0.065844744, 0.080913723, 0.097221188, 0.1101705, 0.12004878, 0.12631439, 0.13109596, 0.13636634, 0.14394984, 0.15403715, 0.16637853, 0.17846046, 0.18850164, 0.19637208, 0.20304862, 0.21020806, 0.21839222, 0.22905919, 0.24069913, 0.25063112, 0.26011643, 0.26819649, 0.27432063, 0.28069636, 0.28867251, 0.2984935, 0.30878478, 0.3183082, 0.3266623, 0.3541904]
stress_10 = [0, 8.7411518, 17.415524, 51.63725, 101.79306, 187.80875, 295.25934, 400.85785, 555.99243, 655.40735, 720.56915, 775.29688, 820.50427, 895.10638, 942.57745, 964.20911, 999.28503, 1021.62292, 1047.7668, 1065.6912, 1084.4846, 1095.7245, 1123.3085, 1140.0184, 1178.3428, 1205.2008, 1228.4016, 1255.882, 1268.9924, 1283.6151, 1306.3633, 1326.4673, 1344.2993, 1358.9744, 1377.2661, 1399.1042, 1419.7035, 1437.9955, 1452.556, 1463.8414, 1469.4736, 1457.3966, 1428.3958, 1415.0342]
    # stress values at 10 s^-1

# Combine into DataFrame
# Append to dictionary
for s, sig in zip(strain_0001, stress_0001):
    data['Strain'].append(s)
    data['LogStrainRate'].append(np.log(0.001))
    data['Temperature'].append(600)
    data['Stress'].append(sig)

for s, sig in zip(strain_1, stress_1):
    data['Strain'].append(s)
    data['LogStrainRate'].append(np.log(1))
    data['Temperature'].append(600)
    data['Stress'].append(sig)

for s, sig in zip(strain_10, stress_10):
    data['Strain'].append(s)
    data['LogStrainRate'].append(np.log(10))
    data['Temperature'].append(600)
    data['Stress'].append(sig)

df = pd.DataFrame(data)

# Display first few data points
print(df)



# Plotting
plt.figure(figsize=(7, 5))
plt.plot(strain_0001, stress_0001, label='Indent 600ºC_0.001', color='blue')
plt.plot(strain_1, stress_1, label='Indent 600ºC_1', color='orange')
plt.plot(strain_10, stress_10, label='Indent 600ºC_10', color='gray')

plt.xlabel('True Strain (ε)', fontsize=12)
plt.ylabel('Stress (σ)', fontsize=12)
plt.title('True Stress vs. Strain at 600°C')
plt.xlim([0, 0.35])
plt.ylim([0, 1600])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#        Strain  LogStrainRate  Temperature       Stress
# 0    0.000000      -6.907755         1000     0.000000
# 1    0.004818      -6.907755         1000    51.469002
# 2    0.006003      -6.907755         1000    65.294082
# 3    0.007417      -6.907755         1000    84.656827
# 4    0.008856      -6.907755         1000   101.619157
# ..        ...            ...          ...          ...
# 469  0.298494       2.302585          600  1463.841400
# 470  0.308785       2.302585          600  1469.473600
# 471  0.318308       2.302585          600  1457.396600
# 472  0.326662       2.302585          600  1428.395800
# 473  0.354190       2.302585          600  1415.034200
#
# [474 rows x 4 columns]
